# %%
import networkx as nx
import matplotlib.pyplot as plt
import uuid
# graphviz is installed already, but need lib too
# !apt install libgraphviz-dev
# !pip install pygraphviz
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgvc6-plugins-gtk
#   librsvg2-common libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk librsvg2-common libxdot4
# 0 upgraded, 9 newly installed, 0 to remove and 49 not upgraded.
# Need to get 2,434 kB of archives.
# After this operation, 7,681 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# ...

# %%
### uuid to generate unique id for leaf labels

# Generate a random UUID
def generate_uuid():
  uuid_str = str(uuid.uuid4())
  return uuid_str

print(generate_uuid())
# Out:
# d43e031f-7864-4a9b-8822-3c0e2067e8e9

# %%
'''
Excluded
Your system is likely excluded from the EU AI Act, which means you do not face any obligations. For more information see Article 2.


Out of scope
Your system is likely outside of the scope of the EU AI Act. For more information about the scope of the Act, please see Article 2.

Prohibited
Your system is likely prohibited under the EU AI Act. For more information see Article 5.

High-risk exception
Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system, and you should:
Comply with any existing regulations;
Stay on the lookout for new developments from the EU and comply with any new regulations.
Article 84 mostly describes obligations for the Commission to regularly review and update the EU AI Act, so the primary obligation for you is to keep an eye on these obligations and maintain compliance.


Excluded: Personal, non-professional activity
Purely personal, non-professional uses of AI systems are likely excluded and are not subject to any obligations. For more information see Article 2 point 5c.


In addition, Each role has its own obligations


'''

# Create a directed graph
#G = nx.DiGraph()

# Create a multi-graph
### Remember to use a multi-graph, different choices may lead to the same question node!!!
G = nx.MultiGraph()

# Add nodes with text labels
G.add_node("Which kind of entity is your organisation?", ### node_id
           theme = "Entity type", ### node theme on top of the question
           source = "Source: Article 3 points 2-8, Recital 87" ### source under the choices
           )
G.add_node("Has a downstream deployer, distributer, or importer made any of the following modifications to your system?",
           theme ="Downstream modifications",
           source = "Source: Article 25 point 2")
# Add edges with text labels
G.add_edge("Which kind of entity is your organisation?", ### node1
           "Has a downstream deployer, distributer, or importer made any of the following modifications to your system?", ### node2
           label = 1, ### label is the order of your choice
           text_label="Provider" ### text_label is the text corresponding to the label
           )

G.add_node("Do you perform any of the following actions?",
           theme ="System modifications",
           source = "Source: Article 25 point 2")
G.add_edge("Which kind of entity is your organisation?", ### node1
           "Do you perform any of the following actions?", ### node2
           key='edge1',
           label = 2, ### label is the order of your choice
           text_label="Deployer" ### text_label is the text corresponding to the label
           )

G.add_edge("Which kind of entity is your organisation?", ### node1
           "Do you perform any of the following actions?", ### node2
           key='edge2',
           label = 3, ### label is the order of your choice
           text_label="Distributor" ### text_label is the text corresponding to the label
           )
G.add_edge("Which kind of entity is your organisation?", ### node1
           "Do you perform any of the following actions?", ### node2
           key='edge3',
           label = 4, ### label is the order of your choice
           text_label="Importer" ### text_label is the text corresponding to the label
           )

### Product manufacturer
G.add_node("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?",
           theme ="Products with AI safety components",
           source = "Source: Article 3 point 14")
G.add_edge("Which kind of entity is your organisation?", ### node1
           "Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node2
           key='edge1',
           label = 5, ### label is the order of your choice
           text_label="Product manufacturer" ### text_label is the text corresponding to the label
           )

G.add_node("Does the AI system in your product meet any of these conditions?",
           theme ="Products with AI safety components",
           source = "Source: Article 3 point 14")
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge1',
           label = 1, ### label is the order of your choice
           text_label="Machinery" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge2',
           label = 2, ### label is the order of your choice
           text_label="Toys" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge2',
           label = 2, ### label is the order of your choice
           text_label="Toys" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge2',
           label = 2, ### label is the order of your choice
           text_label="Toys" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge3',
           label = 3, ### label is the order of your choice
           text_label="Recreational craft & personal watercraft" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge4',
           label = 4, ### label is the order of your choice
           text_label="Lifts and safety components of lifts" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge5',
           label = 5, ### label is the order of your choice
           text_label="Equipment and protective systems intended for use in potentially explosive atmospheres" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge6',
           label = 6, ### label is the order of your choice
           text_label="Radio equipment" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge7',
           label = 7, ### label is the order of your choice
           text_label="Pressure equipment" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge8',
           label = 8, ### label is the order of your choice
           text_label="Cableway installations" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge9',
           label = 9, ### label is the order of your choice
           text_label="Personal protective equipment" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge10',
           label = 10, ### label is the order of your choice
           text_label="Appliances burning gaseous fuels" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge11',
           label = 11, ### label is the order of your choice
           text_label="Medical devices" ### text_label is the text corresponding to the label
           )
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           "Does the AI system in your product meet any of these conditions?", ### node2
           key='edge12',
           label = 12, ### label is the order of your choice
           text_label="In vitro diagnostic medical devices" ### text_label is the text corresponding to the label
           )

### none of above
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Out of scope",
           source = "Source: Article 2")
G.add_edge("Does your product include an AI system as a 'safety component' AND fall within any of the following categories?", ### node1
           result_node, ### node2
           key='edge13',
           label = 13, ### label is the order of your choice
           text_label="None of the above" ### text_label is the text corresponding to the label
           )








G.add_node("Do you meet any of the following criteria?",
           theme = "Scope",
           source = "Source: Article 2")
G.add_edge("Has a downstream deployer, distributer, or importer made any of the following modifications to your system?",
           "Do you meet any of the following criteria?",
           key='edge1',
           label = 1,
           text_label="Putting a different name/trademark on the system")
G.add_edge("Has a downstream deployer, distributer, or importer made any of the following modifications to your system?",
           "Do you meet any of the following criteria?",
           key='edge2',
           label = 2,
           text_label="Modifying the intended purpose of a system already in operation")
G.add_edge("Has a downstream deployer, distributer, or importer made any of the following modifications to your system?",
           "Do you meet any of the following criteria?",
           key='edge3',
           label = 3,
           text_label="Performing a substantial modification (see Article 3 point 23) to the system")
G.add_edge("Has a downstream deployer, distributer, or importer made any of the following modifications to your system?",
           "Do you meet any of the following criteria?",
           key='edge4',
           label = 4,
           text_label="None of the above")


G.add_edge("Does the AI system in your product meet any of these conditions?", ### node1
           "Do you meet any of the following criteria?", ### node2
           key='edge1',
           label = 1, ### label is the order of your choice
           text_label="The AI system was / will be 'placed on the market' together with my product under my manufacturer name or trademark" ### text_label is the text corresponding to the label
           )
G.add_edge("Does the AI system in your product meet any of these conditions?", ### node1
           "Do you meet any of the following criteria?", ### node2
           key='edge2',
           label = 2, ### label is the order of your choice
           text_label="The AI system was / will be 'put into service' under my manufacturer name or trademark after my product has been placed on the market" ### text_label is the text corresponding to the label
           )

### node for Authorised representative (You are considered a 'provider' for the purposes of this legislation under Article 22.)
G.add_edge("Which kind of entity is your organisation?", ### node1
           "Do you meet any of the following criteria?", ### node2
           key='edge6',
           label = 6, ### label is the order of your choice
           text_label="Authorised representative"
           )


### none of above
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Out of scope",
           source = "Source: Article 2")
G.add_edge("Does the AI system in your product meet any of these conditions?", ### node1
           result_node, ### node2
           key='edge3',
           label = 3, ### label is the order of your choice
           text_label="None of the above" ### text_label is the text corresponding to the label
           )
### for Deployer label
'''
Considered a provider
You will be considered a 'provider' for the purposes of this legislation under Article 25 if your system is found to be 'high-risk'. This means you will now continue the form as though you are a provider.

If your system is determined to be 'high-risk' later in this form, you will receive all the relevant obligations of a provider. Otherwise, you will receive your non-provider obligations.
'''
G.add_edge("Do you perform any of the following actions?",
           "Do you meet any of the following criteria?",
           key='edge1',
           label = 1,
           text_label="Putting a different name/trademark on the system")
G.add_edge("Do you perform any of the following actions?",
           "Do you meet any of the following criteria?",
           key='edge2',
           label = 2,
           text_label="Modifying the intended purpose of a system already in operation")
G.add_edge("Do you perform any of the following actions?",
           "Do you meet any of the following criteria?",
           key='edge3',
           label = 3,
           text_label="Performing a substantial modification (see Article 3 point 23) to the system")
G.add_edge("Do you perform any of the following actions?",
           "Do you meet any of the following criteria?",
           key='edge4',
           label = 4,
           text_label="None of the above")




G.add_node("Is your system a General Purpose AI model?",
           theme = "General Purpose AI models",
           source = "Source: Article 3 point 44b")
G.add_edge("Do you meet any of the following criteria?",
           "Is your system a General Purpose AI model?",
           key='edge1',
           label = 1,
           text_label="I am placing on the market or putting into service AI systems in the Union (regardless of whether you are established within the Union or in a third country)")
G.add_edge("Do you meet any of the following criteria?",
           "Is your system a General Purpose AI model?",
           key='edge2',
           label = 2,
           text_label="My AI system's output is used in the EU")
G.add_edge("Do you meet any of the following criteria?",
           "Is your system a General Purpose AI model?",
           key='edge3',
           label = 3,
           text_label="My AI system is located in a non-EU country where 'EU Member State law' applies by virtue of public international law")
G.add_edge("Do you meet any of the following criteria?",
           "Is your system a General Purpose AI model?",
           key='edge4',
           label = 4,
           text_label="My system is considered to be 'prohibited' (see Article 5) and is used by a downstream deployer who is based in the EU")
### none of above
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Out of scope",
           source = "Source: Article 2")
G.add_edge("Do you meet any of the following criteria?",
           result_node,
           label = 5,
           text_label="None of the above")










G.add_node("Does your system fall within any of the following categories?",
           theme = "Excluded systems",
           source = "Source: Article 2")
G.add_edge("Is your system a General Purpose AI model?",
           "Does your system fall within any of the following categories?",
           key='edge1',
           label = 1,
           text_label="Yes")
G.add_edge("Is your system a General Purpose AI model?",
           "Does your system fall within any of the following categories?",
           key='edge2',
           label = 2,
           text_label="No")


#### results node 1
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Excluded",
           source = "Source: Article 2")
G.add_edge("Does your system fall within any of the following categories?",
           result_node,
           label = 1,
           text_label="AI systems developed and used exclusively for military purposes")


#### results node 2
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Excluded",
           source = "Source: Article 2")
G.add_edge("Does your system fall within any of the following categories?",
           result_node,
           label = 2,
           text_label="AI systems used by public authorities or international organisations in third countries for law enforcement and judicial cooperation")




G.add_node("Does your system perform any of these functions?",
           theme = "Prohibited systems",
           source = "Source: Article 5")
G.add_edge("Does your system fall within any of the following categories?",
           "Does your system perform any of these functions?",
           key='edge1',
           label = 3,
           text_label="AI research and development activity")

G.add_edge("Does your system fall within any of the following categories?",
           "Does your system perform any of these functions?",
           key='edge2',
           label = 4,
           text_label="People using AI systems for purely personal, non-professional activity")

G.add_edge("Does your system fall within any of the following categories?",
           "Does your system perform any of these functions?",
           key='edge3',
           label = 5,
           text_label="AI components provided under free and open-source licences")


G.add_edge("Does your system fall within any of the following categories?",
           "Does your system perform any of these functions?",
           key='edge4',
           label = 6,
           text_label="None of the above")



#### results node 3
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 1,
           text_label="Subliminal techniques, manipulation, and deception")

#### results node 4
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 2,
           text_label="Exploiting vulnerabilities")


#### results node 5
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 3,
           text_label="Biometric categorisation")


#### results node 6
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 4,
           text_label="Social scoring")

#### results node 7
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 5,
           text_label="Predictive policing")

#### results node 8
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 6,
           text_label="Expanding facial recognition databases")

#### results node 9
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 7,
           text_label="Emotion recognition")



#### results node 10
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Prohibited",
           source = "Source: Article 5")
G.add_edge("Does your system perform any of these functions?",
           result_node,
           label = 8,
           text_label="Real-time remote biometrics")



G.add_node("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           theme = "High-risk system or safety component",
           source = "Source: Article 3 point 14")
G.add_edge("Does your system perform any of these functions?",
           "Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           label = 9,
           text_label="None of the above")


#### results node 11 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "High-risk exception",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 1,
           text_label="Civil aviation security")


#### results node 12 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
'''
Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system, and you should:

Comply with any existing regulations;
Stay on the lookout for new developments from the EU and comply with any new regulations.
Article 84 mostly describes obligations for the Commission to regularly review and update the EU AI Act, so the primary obligation for you is to keep an eye on these obligations and maintain compliance.
'''
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "High-risk exception",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 2,
           text_label="Two- or three-wheel vehicles and quadricycles")

#### results node 13 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "High-risk exception",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 3,
           text_label="Agricultural and forestry vehicles")



#### results node 14 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "High-risk exception",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 4,
           text_label="Marine equipment")

#### results node 15 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "High-risk exception",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 5,
           text_label="Interoperability of the rail systems")
#### results node 16 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "High-risk exception",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 6,
           text_label="Motor vehicles and their trailers")
#### results node 17 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "High-risk exception",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 7,
           text_label="Civil aviation")


#### results node 18 -> Your system likely falls under an Article 2 exception. This means that only Article 112 applies to your system
'''
Handover obligations
If a deployer, distributer, or importer makes a 'substantial modification' (see Article 3 point 23) to your system, they will be considered a 'provider' of that system under Article 25. The original provider will not longer be considered a provider of that particular system.

However, the original provider will have obligations to provide the new provider with:

Technical documentation.
Information about the capabilities of the AI system.
Technical access.
Assistance to help the new provider fulfil their obligations under the Act.
'''
result_node = f"Result_Node: {generate_uuid()}"
G.add_node(result_node,
           theme = "Result",
           result = "Handover obligations",
           source = "Source: Article 2, Article 112")
G.add_edge("Does your AI system (or the product for which your AI system is a 'safety component') fall within any of the following high-risk categories?",
           result_node,
           label = 8,
           text_label="None of the above")



















####### Draw the graph
#pos = nx.spring_layout(G, k=1)  # positions for all nodes
# Use graphviz_layout for a tree structure
pos = nx.nx_agraph.graphviz_layout(G, prog='dot', args='-Granksep=2 -Gnodesep=1')
# Draw nodes and edges
#nx.draw(G, pos, with_labels=True, node_size=2000, node_color="lightblue", font_size=10)
nx.draw(G, pos, with_labels=False, node_size=500, node_color="lightblue", font_size=6)
# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
#truncated_labels = {k: v[:20] for k, v in edge_labels.items()}
# Get node labels and truncate them to 15 characters
truncated_names = {node: node[:5] for node in G.nodes}
#

# Draw truncated node names
nx.draw_networkx_labels(G, pos, labels=truncated_names)
nx.draw_networkx_edge_labels(G, pos,  edge_labels=edge_labels)
# Show the graph
plt.title("Graph with Textual Nodes and Edges")
plt.show()

# %%
from pprint import pprint

print(G.nodes[result_node].get('result', -1))
#print(G.nodes["Does your system fall within any of the following categories?"].get('result', -1))
print(G["Does your system fall within any of the following categories?"])
# Out:
# Handover obligations
# {'Is your system a General Purpose AI model?': {0: {'label': 1, 'text_label': 'Yes'}}, 'Result_Node: e93f7b8e-36c0-4854-b3b3-a845ec005954': {0: {'label': 1, 'text_label': 'AI systems developed and used exclusively for military purposes'}}, 'Result_Node: cfb38431-9885-4346-aa4f-483bfdaac901': {0: {'label': 2, 'text_label': 'AI systems used by public authorities or international organisations in third countries for law enforcement and judicial cooperation'}}, 'Does your system perform any of these functions?': {'edge1': {'label': 3, 'text_label': 'AI research and development activity'}, 'edge2': {'label': 4, 'text_label': 'People using AI systems for purely personal, non-professional activity'}}}
